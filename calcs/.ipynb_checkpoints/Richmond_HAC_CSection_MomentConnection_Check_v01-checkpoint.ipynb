# %% [markdown]
# # Richmond HAC — Modified C-Section Moment Connection
#
# **Independent limit-state check — AISC 360-22 (LRFD), ASCE 7-22 demands**
#
# An **HSS 7x4x3/8** beam (centered on the column WP) nests inside an 11.5"-long
# **HSS 8x6x3/8** stub that is coped (one web removed) into an open C. The stub is
# CJP-welded to a **PL 3/4 x 16 x 6** cover plate, which is fillet-welded (5/16",
# all around) to an **HSS 6x6x3/8** column. The beam is shimmed snug (bottom + sides)
# with 1/2" end clearance and fastened with **three 1" dia F2280 bolts** (STD holes,
# bearing-type, double shear) through the flange sandwich.
#
# **Axes** — x along the beam, y vertical (8"/7" dim), z horizontal (6"/4" dim).
#
# | material | Fy | Fu |
# |---|---|---|
# | HSS A500 Gr.C | 50 | 62 |
# | PL A572-50 | 50 | 65 |
# | weld E70 | — | FEXX = 70 |
#
# > **Critical modeling premise — Path A.** The major moment `Muz` is carried as a
# > horizontal flange couple through the **bolts in double shear**, *not* by vertical
# > bearing in the pocket. This is what keeps the seat flange a `Vuy`-only check
# > (Section 9). If any moment rides on vertical bearing, the seat force jumps from
# > ~9 k to 30-85 k and the seat-flange conclusion no longer holds.
#
# > Scope: a peer check to compare against the design calcs; not an EOR sign-off.

# %%
# %%capture

# --- Environment setup -------------------------------------------------
# !pip install handcalcs
# !pip install forallpeople
# !pip install numpy
# !pip install pandas

import sys
import os
# Tell Python to look in the parent directory (Project_Root) for your modules
sys.path.append(os.path.abspath('..'))

import handcalcs.render                     # registers the %%render cell magic
import forallpeople as si
si.environment('structural')            # units become si.* attributes

# pull the structural units into the notebook namespace
kip, lb, inch, ft   = si.kip, si.lb, si.inch, si.ft
ksi, psi, ksf, psf  = si.ksi, si.psi, si.ksf, si.psf

# helper modules (uploaded alongside this notebook)
from helpers.sigfigs import setup_formatting, sig   # 3-sig-fig handcalcs patch + sig() for text
from helpers.exporter import export_notebook        # absolute-path HTML/PDF export
setup_formatting(3)

# NOTE: work strictly in kip and inch (never ft) so derived forces/moments/stresses
# stay in kip / kip-in / ksi instead of collapsing to SI.

# %% [markdown]
# ## 1  Geometry & fastener data

# %%
# %%render params
# t      = 0.349*inch      # design wall = 0.93 x 3/8 (all HSS)
# d_beam = 7*inch
# b_beam = 4*inch
# d_stub = 8*inch
# b_stub = 6*inch
# B_col  = 6*inch
# L_stub = 11.5*inch
# d_b    = 1.0*inch        # bolt diameter
# A_b    = 0.785*inch**2   # bolt area
# d_h    = 1.0625*inch     # STD hole
# n_b    = 3               # bolts
# s_p    = 3*inch          # pitch and edge distance
# w_leg  = 0.3125*inch     # fillet weld leg
# t_pl   = 0.75*inch       # cover plate thickness
# b_w    = 6*inch          # weld group width  (z)
# d_w    = 16*inch         # weld group depth  (y)
# Out:
# $$
# \begin{aligned}
# t &= 0.349\ \mathrm{inch} \; \;\textrm{(design wall = 0.93 x 3/8 (all HSS))}
#  &d_{beam} &= 7.000\ \mathrm{inch} \;
# \\
#  b_{beam} &= 4.000\ \mathrm{inch} \;
#  &d_{stub} &= 8.000\ \mathrm{inch} \;
# \\
#  b_{stub} &= 6.000\ \mathrm{inch} \;
#  &B_{col} &= 6.000\ \mathrm{inch} \;
# \\
#  L_{stub} &= 11.500\ \mathrm{inch} \;
#  &d_{b} &= 1.000\ \mathrm{inch} \; \;\textrm{(bolt diameter)}
# \\
#  A_{b} &= 0.785\ \mathrm{inch}^{2} \; \;\textrm{(bolt area)}
#  &d_{h} &= 1.062\ \mathrm{inch} \; \;\textrm{(STD hole)}
# \\
#  n_{b} &= 3 \; \;\textrm{(bolts)}
#  &s_{p} &= 3.000\ \mathrm{inch} \; \;\textrm{(pitch and edge distance)}
# \\
#  w_{leg} &= 0.312\ \mathrm{inch} \; \;\textrm{(fillet weld leg)}
#  &t_{pl} &= 0.750\ \mathrm{inch} \; \;\textrm{(cover plate thickness)}
# \\
#  b_{w} &= 6.000\ \mathrm{inch} \; \;\textrm{(weld group width  (z))}
#  &d_{w} &= 16.000\ \mathrm{inch} \; \;\textrm{(weld group depth  (y))}
# \\
# \end{aligned}
# $$

# %% [markdown]
# ## 2  Materials & factored demands (at the column-CL work point)

# %%
# %%render params
# F_y   = 50*ksi
# F_u   = 62*ksi
# F_yp  = 50*ksi
# F_up  = 65*ksi
# F_EXX = 70*ksi
# phi   = 0.75             # bolt / weld rupture
# M_uz  = 424.8*kip*inch   # 35.4 kip-ft  major moment (about z)
# M_uy  = 47.6*kip*inch    # 3.97 kip-ft  minor moment (about y)
# T_u   = 8.52*kip*inch    # 0.71 kip-ft  torsion (about x)
# P_c   = 11.4*kip         # axial compression
# P_t   = 5.8*kip          # axial tension
# V_uy  = 8.9*kip          # vertical shear
# V_uz  = 1.0*kip          # horizontal shear
# F_nv  = 68*ksi           # F2280 (Group 150), threads included (N)
# F_nt  = 113*ksi
# Out:
# $$
# \begin{aligned}
# F_{y} &= 50.000\ \mathrm{ksi} \;
#  &F_{u} &= 62.000\ \mathrm{ksi} \;
# \\
#  F_{yp} &= 50.000\ \mathrm{ksi} \;
#  &F_{up} &= 65.000\ \mathrm{ksi} \;
# \\
#  F_{EXX} &= 70.000\ \mathrm{ksi} \;
#  &\phi &= 0.75 \; \;\textrm{(bolt / weld rupture)}
# \\
#  M_{uz} &= 424.800\ \mathrm{kip} \cdot \mathrm{in} \; \;\textrm{(35.4 kip-ft  major moment (about z))}
#  &M_{uy} &= 47.600\ \mathrm{kip} \cdot \mathrm{in} \; \;\textrm{(3.97 kip-ft  minor moment (about y))}
# \\
#  T_{u} &= 8.520\ \mathrm{kip} \cdot \mathrm{in} \; \;\textrm{(0.71 kip-ft  torsion (about x))}
#  &P_{c} &= 11.400\ \mathrm{kip} \; \;\textrm{(axial compression)}
# \\
#  P_{t} &= 5.800\ \mathrm{kip} \; \;\textrm{(axial tension)}
#  &V_{uy} &= 8.900\ \mathrm{kip} \; \;\textrm{(vertical shear)}
# \\
#  V_{uz} &= 1.000\ \mathrm{kip} \; \;\textrm{(horizontal shear)}
#  &F_{nv} &= 68.000\ \mathrm{ksi} \; \;\textrm{(F2280 (Group 150), threads included (N))}
# \\
#  F_{nt} &= 113.000\ \mathrm{ksi} \;
# \end{aligned}
# $$

# %% [markdown]
# ## 3  Bolts — shear (double shear)
#
# `Muz` resolves to a horizontal flange couple `F_flange = Muz/(d_beam - t)` shared
# by the 3 bolts; axial, `Muy` (elastic group), `Vuz` and torsion add in-plane shear.
# Worst shear plane, combined as vector components.

# %%
# %%render
# d_bf     = d_beam - t                    # beam flange centroid separation
# F_flange = M_uz / d_bf                   # horizontal flange couple force
# c_b      = 3*inch                        # end bolt to group centroid
# J_b      = 18*inch**2                    # sum of x squared for the 3 bolts
# V_x      = F_flange/n_b + P_c/(n_b*2)    # x shear per plane, couple plus axial
# V_z      = M_uy*c_b/J_b/2 + V_uz/(n_b*2) + T_u/d_bf/n_b   # z shear per plane
# V_bolt   = (V_x**2 + V_z**2)**0.5        # resultant per shear plane
# R_n      = phi*F_nv*A_b                  # capacity per shear plane
# DCR_bolt_shear = V_bolt / R_n
# Out:
# $$
# \begin{aligned}
# d_{bf} &= d_{beam} - t  = 7.000\ \mathrm{inch} - 0.349\ \mathrm{inch} &= 6.651\ \mathrm{inch} \; \;\textrm{(beam flange centroid separation)}
# \\
# F_{flange} &= \frac{ M_{uz} }{ d_{bf} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 6.651\ \mathrm{inch} } &= 63.870\ \mathrm{kip} \; \;\textrm{(horizontal flange couple force)}
# \\
# c_{b} &= 3 \cdot \mathrm{inch}  = 3 \cdot 1.000\ \mathrm{inch} &= 3.000\ \mathrm{inch} \; \;\textrm{(end bolt to group centroid)}
# \\
# J_{b} &= 18 \cdot \left( \mathrm{inch} \right) ^{ 2 }  = 18 \cdot \left( 1.000\ \mathrm{inch} \right) ^{ 2 } &= 18.000\ \mathrm{inch}^{2} \; \;\textrm{(sum of x squared for the 3 bolts)}
# \\
# V_{x} &= \frac{ F_{flange} }{ n_{b} } + \frac{ P_{c} }{ n_{b} \cdot 2 }  = \frac{ 63.870\ \mathrm{kip} }{ 3 } + \frac{ 11.400\ \mathrm{kip} }{ 3 \cdot 2 } &= 23.190\ \mathrm{kip} \; \;\textrm{(x shear per plane, couple plus axial)}
# \\
# V_{z} &= M_{uy} \cdot \frac{ c_{b} }{ J_{b} } \cdot \frac{1} { 2 } + \frac{ V_{uz} }{ n_{b} \cdot 2 } + \frac{ T_{u} }{ d_{bf} } \cdot \frac{1} { n_{b} }  = 47.600\ \mathrm{kip} \cdot \mathrm{in} \cdot \frac{ 3.000\ \mathrm{inch} }{ 18.000\ \mathrm{inch}^{2} } \cdot \frac{1} { 2 } + \frac{ 1.000\ \mathrm{kip} }{ 3 \cdot 2 } + \frac{ 8.520\ \mathrm{kip} \cdot \mathrm{in} }{ 6.651\ \mathrm{inch} } \cdot \frac{1} { 3 } &= 4.560\ \mathrm{kip} \; \;\textrm{(z shear per plane)}
# \\
# V_{bolt} &= \left( \left( V_{x} \right) ^{ 2 } + \left( V_{z} \right) ^{ 2 } \right) ^{ 0.5 }  = \left( \left( 23.190\ \mathrm{kip} \right) ^{ 2 } + \left( 4.560\ \mathrm{kip} \right) ^{ 2 } \right) ^{ 0.5 } &= 105.130\ \mathrm{kN} \; \;\textrm{(resultant per shear plane)}
# \\
# R_{n} &= \phi \cdot F_{nv} \cdot A_{b}  = 0.75 \cdot 68.000\ \mathrm{ksi} \cdot 0.785\ \mathrm{inch}^{2} &= 40.035\ \mathrm{kip} \; \;\textrm{(capacity per shear plane)}
# \\
# \mathrm{DCR}_{bolt_{shear}} &= \frac{ V_{bolt} }{ R_{n} }  = \frac{ 105.130\ \mathrm{kN} }{ 40.035\ \mathrm{kip} } &= 0.59
# \end{aligned}
# $$

# %% [markdown]
# ## 3b  Bolts — bearing / tearout (per ply, flange t = 0.349)
#
# Governing clear distance is the 3" pitch (`lc = 3 - d_h`). Same for beam and stub
# flanges; the 3/4" cover plate is not on the bolt line.

# %%
# %%render
# l_c    = s_p - d_h                       # clear distance, pitch controls
# R_brg  = phi*2.4*d_b*t*F_u               # bearing
# R_to   = phi*1.2*l_c*t*F_u               # tearout
# R_bt   = min(R_brg, R_to)
# DCR_bolt_bearing = V_bolt / R_bt
# Out:
# $$
# \begin{aligned}
# l_{c} &= s_{p} - d_{h}  = 3.000\ \mathrm{inch} - 1.062\ \mathrm{inch} &= 1.937\ \mathrm{inch} \; \;\textrm{(clear distance, pitch controls)}
# \\
# R_{brg} &= \phi \cdot 2.4 \cdot d_{b} \cdot t \cdot F_{u}  = 0.75 \cdot 2.4 \cdot 1.000\ \mathrm{inch} \cdot 0.349\ \mathrm{inch} \cdot 62.000\ \mathrm{ksi} &= 38.948\ \mathrm{kip} \; \;\textrm{(bearing)}
# \\
# R_{to} &= \phi \cdot 1.2 \cdot l_{c} \cdot t \cdot F_{u}  = 0.75 \cdot 1.2 \cdot 1.937\ \mathrm{inch} \cdot 0.349\ \mathrm{inch} \cdot 62.000\ \mathrm{ksi} &= 37.731\ \mathrm{kip} \; \;\textrm{(tearout)}
# \\
# R_{bt} &= \operatorname{min} \left( R_{brg} ,\  R_{to} \right)  = \operatorname{min} \left( 38.948\ \mathrm{kip} ,\  37.731\ \mathrm{kip} \right) &= 37.731\ \mathrm{kip}
# \\
# \mathrm{DCR}_{bolt_{bearing}} &= \frac{ V_{bolt} }{ R_{bt} }  = \frac{ 105.130\ \mathrm{kN} }{ 37.731\ \mathrm{kip} } &= 0.626
# \end{aligned}
# $$

# %% [markdown]
# ## 4  Beam tension-flange rupture (AISC F13)
#
# Vertical bolts hole both flanges. With `Fy/Fu = 0.81 > 0.8`, `Yt = 1.1`; since
# `Fu*Afn < Yt*Fy*Afg`, holes govern flexure and `Mn = (Fu*Afn/Afg)*Sx`.
# `Sx` here is the gross-box value (corner radii ignored) — confirm against the
# AISC table; non-governing either way.

# %%
# %%render
# A_fg  = b_beam*t                         # gross flange (top wall)
# A_fn  = (b_beam - d_h)*t                 # net flange at a hole
# Y_t   = 1.1
# b_i   = b_beam - 2*t
# h_i   = d_beam - 2*t
# I_x   = (b_beam*d_beam**3 - b_i*h_i**3)/12
# S_x   = I_x/(d_beam/2)
# M_n   = (F_u*A_fn/A_fg)*S_x              # F13-1 cap (Fu*Afn < Yt*Fy*Afg)
# phiM_n = 0.9*M_n
# DCR_beam_flange = M_uz/phiM_n
# Out:
# $$
# \begin{aligned}
# A_{fg} &= b_{beam} \cdot t  = 4.000\ \mathrm{inch} \cdot 0.349\ \mathrm{inch} &= 1.396\ \mathrm{inch}^{2} \; \;\textrm{(gross flange (top wall))}
# \\
# A_{fn} &= \left( b_{beam} - d_{h} \right) \cdot t  = \left( 4.000\ \mathrm{inch} - 1.062\ \mathrm{inch} \right) \cdot 0.349\ \mathrm{inch} &= 1.025\ \mathrm{inch}^{2} \; \;\textrm{(net flange at a hole)}
# \\
# Y_{t} &= 1.1 \;
# \\
# b_{i} &= b_{beam} - 2 \cdot t  = 4.000\ \mathrm{inch} - 2 \cdot 0.349\ \mathrm{inch} &= 3.302\ \mathrm{inch}
# \\
# h_{i} &= d_{beam} - 2 \cdot t  = 7.000\ \mathrm{inch} - 2 \cdot 0.349\ \mathrm{inch} &= 6.302\ \mathrm{inch}
# \\
# I_{x} &= \frac{ b_{beam} \cdot \left( d_{beam} \right) ^{ 3 } - b_{i} \cdot \left( h_{i} \right) ^{ 3 } }{ 12 }  = \frac{ 4.000\ \mathrm{inch} \cdot \left( 7.000\ \mathrm{inch} \right) ^{ 3 } - 3.302\ \mathrm{inch} \cdot \left( 6.302\ \mathrm{inch} \right) ^{ 3 } }{ 12 } &= 45.463\ \mathrm{inch}^{4}
# \\
# S_{x} &= \frac{ I_{x} }{ \frac{ d_{beam} }{ 2 } }  = \frac{ 45.463\ \mathrm{inch}^{4} }{ \frac{ 7.000\ \mathrm{inch} }{ 2 } } &= 12.989\ \mathrm{inch}^{3}
# \\
# M_{n} &= \left( F_{u} \cdot \frac{ A_{fn} }{ A_{fg} } \right) \cdot S_{x}  = \left( 62.000\ \mathrm{ksi} \cdot \frac{ 1.025\ \mathrm{inch}^{2} }{ 1.396\ \mathrm{inch}^{2} } \right) \cdot 12.989\ \mathrm{inch}^{3} &= 591.427\ \mathrm{kip} \cdot \mathrm{in} \; \;\textrm{(F13-1 cap (Fu*Afn < Yt*Fy*Afg))}
# \\
# \mathrm{phiM}_{n} &= 0.9 \cdot M_{n}  = 0.9 \cdot 591.427\ \mathrm{kip} \cdot \mathrm{in} &= 532.285\ \mathrm{kip} \cdot \mathrm{in}
# \\
# \mathrm{DCR}_{beam_{flange}} &= \frac{ M_{uz} }{ \mathrm{phiM}_{n} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 532.285\ \mathrm{kip} \cdot \mathrm{in} } &= 0.798
# \end{aligned}
# $$

# %% [markdown]
# ## 5  Fillet weld group — plate to column (5/16", E70)
#
# Elastic weld-line method, perimeter 16 x 6. Critical point is the corner (normal
# stress from `Muz` + `Muy` + `P`; in-plane shear is small).

# %%
# %%render
# L_w    = 2*(b_w + d_w)                    # total weld length
# I_xw   = d_w**3/6 + b_w*d_w**2/2          # weld line, about z
# S_xw   = I_xw/(d_w/2)
# I_yw   = b_w**3/6 + d_w*b_w**2/2          # about y
# S_yw   = I_yw/(b_w/2)
# f_M    = M_uz/S_xw                        # normal, from Muz
# f_My   = M_uy/S_yw                        # normal, from Muy
# f_P    = P_c/L_w                          # normal, from axial
# f_weld = f_M + f_My + f_P                 # corner resultant, normal governs
# t_thr  = 0.707*w_leg
# R_nw   = phi*0.6*F_EXX*t_thr              # base capacity per length
# DCR_weld_base = f_weld/R_nw
# Out:
# $$
# \begin{aligned}
# L_{w} &= 2 \cdot \left( b_{w} + d_{w} \right)  = 2 \cdot \left( 6.000\ \mathrm{inch} + 16.000\ \mathrm{inch} \right) &= 44.000\ \mathrm{inch} \; \;\textrm{(total weld length)}
# \\
# I_{xw} &= \frac{ \left( d_{w} \right) ^{ 3 } }{ 6 } + b_{w} \cdot \frac{ \left( d_{w} \right) ^{ 2 } }{ 2 }  = \frac{ \left( 16.000\ \mathrm{inch} \right) ^{ 3 } }{ 6 } + 6.000\ \mathrm{inch} \cdot \frac{ \left( 16.000\ \mathrm{inch} \right) ^{ 2 } }{ 2 } &= 1450.667\ \mathrm{inch}^{3} \; \;\textrm{(weld line, about z)}
# \\
# S_{xw} &= \frac{ I_{xw} }{ \frac{ d_{w} }{ 2 } }  = \frac{ 1450.667\ \mathrm{inch}^{3} }{ \frac{ 16.000\ \mathrm{inch} }{ 2 } } &= 181.333\ \mathrm{inch}^{2}
# \\
# I_{yw} &= \frac{ \left( b_{w} \right) ^{ 3 } }{ 6 } + d_{w} \cdot \frac{ \left( b_{w} \right) ^{ 2 } }{ 2 }  = \frac{ \left( 6.000\ \mathrm{inch} \right) ^{ 3 } }{ 6 } + 16.000\ \mathrm{inch} \cdot \frac{ \left( 6.000\ \mathrm{inch} \right) ^{ 2 } }{ 2 } &= 324.000\ \mathrm{inch}^{3} \; \;\textrm{(about y)}
# \\
# S_{yw} &= \frac{ I_{yw} }{ \frac{ b_{w} }{ 2 } }  = \frac{ 324.000\ \mathrm{inch}^{3} }{ \frac{ 6.000\ \mathrm{inch} }{ 2 } } &= 108.000\ \mathrm{inch}^{2}
# \\
# f_{M} &= \frac{ M_{uz} }{ S_{xw} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 181.333\ \mathrm{inch}^{2} } &= 410.260\ \mathrm{kN/m} \; \;\textrm{(normal, from Muz)}
# \\
# f_{My} &= \frac{ M_{uy} }{ S_{yw} }  = \frac{ 47.600\ \mathrm{kip} \cdot \mathrm{in} }{ 108.000\ \mathrm{inch}^{2} } &= 77.186\ \mathrm{kN/m} \; \;\textrm{(normal, from Muy)}
# \\
# f_{P} &= \frac{ P_{c} }{ L_{w} }  = \frac{ 11.400\ \mathrm{kip} }{ 44.000\ \mathrm{inch} } &= 45.374\ \mathrm{kN/m} \; \;\textrm{(normal, from axial)}
# \\
# f_{weld} &= f_{M} + f_{My} + f_{P}  = 410.260\ \mathrm{kN/m} + 77.186\ \mathrm{kN/m} + 45.374\ \mathrm{kN/m} &= 532.820\ \mathrm{kN/m} \; \;\textrm{(corner resultant, normal governs)}
# \\
# t_{thr} &= 0.707 \cdot w_{leg}  = 0.707 \cdot 0.312\ \mathrm{inch} &= 0.221\ \mathrm{inch}
# \\
# R_{nw} &= \phi \cdot 0.6 \cdot F_{EXX} \cdot t_{thr}  = 0.75 \cdot 0.6 \cdot 70.000\ \mathrm{ksi} \cdot 0.221\ \mathrm{inch} &= 1.219\ \mathrm{MN/m} \; \;\textrm{(base capacity per length)}
# \\
# \mathrm{DCR}_{weld_{base}} &= \frac{ f_{weld} }{ R_{nw} }  = \frac{ 532.820\ \mathrm{kN/m} }{ 1.219\ \mathrm{MN/m} } &= 0.437
# \end{aligned}
# $$

# %% [markdown]
# **Chapter K5 effective width.** The transverse (top/bottom) welds on the 6x6
# face are only partly effective; `be = (10/(B/t))(Fy*t/(Fyp*tp))*bw`. Reducing the
# top/bottom weld to `be` raises the effective stress.

# %%
# %%render
# b_e     = (10/(B_col/t))*(F_y*t/(F_yp*t_pl))*b_w
# I_xwe   = d_w**3/6 + b_e*d_w**2/2
# S_xwe   = I_xwe/(d_w/2)
# f_Me    = M_uz/S_xwe
# f_welde = f_Me + f_My + f_P
# DCR_weld_K5 = f_welde/R_nw
# Out:
# $$
# \begin{aligned}
# b_{e} &= \left( \frac{ 10 }{ \frac{ B_{col} }{ t } } \right) \cdot \left( F_{y} \cdot \frac{ t }{ F_{yp} \cdot t_{pl} } \right) \cdot b_{w} \\&= \left( \frac{ 10 }{ \frac{ 6.000\ \mathrm{inch} }{ 0.349\ \mathrm{inch} } } \right) \cdot \left( 50.000\ \mathrm{ksi} \cdot \frac{ 0.349\ \mathrm{inch} }{ 50.000\ \mathrm{ksi} \cdot 0.750\ \mathrm{inch} } \right) \cdot 6.000\ \mathrm{inch} \\&= 1.624\ \mathrm{inch}  \\
# \\
# I_{xwe} &= \frac{ \left( d_{w} \right) ^{ 3 } }{ 6 } + b_{e} \cdot \frac{ \left( d_{w} \right) ^{ 2 } }{ 2 }  = \frac{ \left( 16.000\ \mathrm{inch} \right) ^{ 3 } }{ 6 } + 1.624\ \mathrm{inch} \cdot \frac{ \left( 16.000\ \mathrm{inch} \right) ^{ 2 } }{ 2 } &= 890.540\ \mathrm{inch}^{3}
# \\
# S_{xwe} &= \frac{ I_{xwe} }{ \frac{ d_{w} }{ 2 } }  = \frac{ 890.540\ \mathrm{inch}^{3} }{ \frac{ 16.000\ \mathrm{inch} }{ 2 } } &= 111.318\ \mathrm{inch}^{2}
# \\
# f_{Me} &= \frac{ M_{uz} }{ S_{xwe} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 111.318\ \mathrm{inch}^{2} } &= 668.303\ \mathrm{kN/m}
# \\
# f_{welde} &= f_{Me} + f_{My} + f_{P}  = 668.303\ \mathrm{kN/m} + 77.186\ \mathrm{kN/m} + 45.374\ \mathrm{kN/m} &= 790.863\ \mathrm{kN/m}
# \\
# \mathrm{DCR}_{weld_{K5}} &= \frac{ f_{welde} }{ R_{nw} }  = \frac{ 790.863\ \mathrm{kN/m} }{ 1.219\ \mathrm{MN/m} } &= 0.649
# \end{aligned}
# $$

# %% [markdown]
# ## 6  Cover plate — flexural yielding (3/4 x 16, about z)

# %%
# %%render
# S_p   = t_pl*d_w**2/6
# sig_p = M_uz/S_p
# DCR_plate = sig_p/(0.9*F_yp)
# Out:
# $$
# \begin{aligned}
# S_{p} &= t_{pl} \cdot \frac{ \left( d_{w} \right) ^{ 2 } }{ 6 }  = 0.750\ \mathrm{inch} \cdot \frac{ \left( 16.000\ \mathrm{inch} \right) ^{ 2 } }{ 6 } &= 32.000\ \mathrm{inch}^{3}
# \\
# \mathrm{sig}_{p} &= \frac{ M_{uz} }{ S_{p} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 32.000\ \mathrm{inch}^{3} } &= 13.275\ \mathrm{ksi}
# \\
# \mathrm{DCR}_{plate} &= \frac{ \mathrm{sig}_{p} }{ 0.9 \cdot F_{yp} }  = \frac{ 13.275\ \mathrm{ksi} }{ 0.9 \cdot 50.000\ \mathrm{ksi} } &= 0.295
# \end{aligned}
# $$

# %% [markdown]
# Plate thickness 3/4" exceeds the ~5/8" needed for the interface yield-line — OK.

# %% [markdown]
# ## 7  Column HSS wall — beta = bp/B = 6/6 = 1.0
#
# Full-width plate loads the side walls directly (efficient); punching shear need
# not be checked at beta = 1. Side-wall yielding under the compression flange force
# `C = Muz/d_couple` (approx; assumed bearing length 5", confirm with a clean K check).

# %%
# %%render
# d_cp   = d_w - 2*inch                     # couple arm, forces near plate edges
# C_fl   = M_uz/d_cp                        # compression flange force
# N_eff  = 5*inch                           # assumed comp bearing length
# R_sw   = 2*F_y*t*N_eff                    # two side walls
# DCR_col_wall = C_fl/R_sw
# Out:
# $$
# \begin{aligned}
# d_{cp} &= d_{w} - 2 \cdot \mathrm{inch}  = 16.000\ \mathrm{inch} - 2 \cdot 1.000\ \mathrm{inch} &= 14.000\ \mathrm{inch} \; \;\textrm{(couple arm, forces near plate edges)}
# \\
# C_{fl} &= \frac{ M_{uz} }{ d_{cp} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 14.000\ \mathrm{inch} } &= 30.343\ \mathrm{kip} \; \;\textrm{(compression flange force)}
# \\
# N_{eff} &= 5 \cdot \mathrm{inch}  = 5 \cdot 1.000\ \mathrm{inch} &= 5.000\ \mathrm{inch} \; \;\textrm{(assumed comp bearing length)}
# \\
# R_{sw} &= 2 \cdot F_{y} \cdot t \cdot N_{eff}  = 2 \cdot 50.000\ \mathrm{ksi} \cdot 0.349\ \mathrm{inch} \cdot 5.000\ \mathrm{inch} &= 174.500\ \mathrm{kip} \; \;\textrm{(two side walls)}
# \\
# \mathrm{DCR}_{col_{wall}} &= \frac{ C_{fl} }{ R_{sw} }  = \frac{ 30.343\ \mathrm{kip} }{ 174.500\ \mathrm{kip} } &= 0.174
# \end{aligned}
# $$

# %% [markdown]
# ## 8  Stub C-section (8x6x3/8, one 8-web removed)
#
# Flexure about z (2 flanges + 1 web), shear on the remaining web, and St-Venant
# torsion of the open section (warping additional — verify combined with flexural
# shear given the CJP-restrained end).

# %%
# %%render
# y_f    = (d_stub - t)/2
# h_w    = d_stub - 2*t
# I_zs   = 2*(b_stub*t*y_f**2) + t*h_w**3/12
# S_zs   = I_zs/(d_stub/2)
# phiM_s = 0.9*F_y*S_zs
# DCR_stub_flex = M_uz/phiM_s
#
# A_ws   = h_w*t                            # remaining web
# phiV_s = 0.6*F_y*A_ws
# DCR_stub_shear = V_uy/phiV_s
#
# J_o    = (b_stub + b_stub + h_w)*t**3/3   # open-section torsion constant
# tau_t  = T_u*t/J_o                        # St-Venant shear stress
# Out:
# $$
# \begin{aligned}
# y_{f} &= \frac{ d_{stub} - t }{ 2 }  = \frac{ 8.000\ \mathrm{inch} - 0.349\ \mathrm{inch} }{ 2 } &= 3.825\ \mathrm{inch}
# \\
# h_{w} &= d_{stub} - 2 \cdot t  = 8.000\ \mathrm{inch} - 2 \cdot 0.349\ \mathrm{inch} &= 7.302\ \mathrm{inch}
# \\
# I_{zs} &= 2 \cdot \left( b_{stub} \cdot t \cdot \left( y_{f} \right) ^{ 2 } \right) + t \cdot \frac{ \left( h_{w} \right) ^{ 3 } }{ 12 } \\&= 2 \cdot \left( 6.000\ \mathrm{inch} \cdot 0.349\ \mathrm{inch} \cdot \left( 3.825\ \mathrm{inch} \right) ^{ 2 } \right) + 0.349\ \mathrm{inch} \cdot \frac{ \left( 7.302\ \mathrm{inch} \right) ^{ 3 } }{ 12 } \\&= 72.612\ \mathrm{inch}^{4}  \\
# \\
# S_{zs} &= \frac{ I_{zs} }{ \frac{ d_{stub} }{ 2 } }  = \frac{ 72.612\ \mathrm{inch}^{4} }{ \frac{ 8.000\ \mathrm{inch} }{ 2 } } &= 18.153\ \mathrm{inch}^{3}
# \\
# \mathrm{phiM}_{s} &= 0.9 \cdot F_{y} \cdot S_{zs}  = 0.9 \cdot 50.000\ \mathrm{ksi} \cdot 18.153\ \mathrm{inch}^{3} &= 816.888\ \mathrm{kip} \cdot \mathrm{in}
# \\
# \mathrm{DCR}_{stub_{flex}} &= \frac{ M_{uz} }{ \mathrm{phiM}_{s} }  = \frac{ 424.800\ \mathrm{kip} \cdot \mathrm{in} }{ 816.888\ \mathrm{kip} \cdot \mathrm{in} } &= 0.52
# \\
# A_{ws} &= h_{w} \cdot t  = 7.302\ \mathrm{inch} \cdot 0.349\ \mathrm{inch} &= 2.548\ \mathrm{inch}^{2} \; \;\textrm{(remaining web)}
# \\
# \mathrm{phiV}_{s} &= 0.6 \cdot F_{y} \cdot A_{ws}  = 0.6 \cdot 50.000\ \mathrm{ksi} \cdot 2.548\ \mathrm{inch}^{2} &= 76.452\ \mathrm{kip}
# \\
# \mathrm{DCR}_{stub_{shear}} &= \frac{ V_{uy} }{ \mathrm{phiV}_{s} }  = \frac{ 8.900\ \mathrm{kip} }{ 76.452\ \mathrm{kip} } &= 0.116
# \\
# J_{o} &= \left( b_{stub} + b_{stub} + h_{w} \right) \cdot \frac{ \left( t \right) ^{ 3 } }{ 3 }  = \left( 6.000\ \mathrm{inch} + 6.000\ \mathrm{inch} + 7.302\ \mathrm{inch} \right) \cdot \frac{ \left( 0.349\ \mathrm{inch} \right) ^{ 3 } }{ 3 } &= 0.274\ \mathrm{inch}^{4} \; \;\textrm{(open-section torsion constant)}
# \\
# \tau_{t} &= T_{u} \cdot \frac{ t }{ J_{o} }  = 8.520\ \mathrm{kip} \cdot \mathrm{in} \cdot \frac{ 0.349\ \mathrm{inch} }{ 0.274\ \mathrm{inch}^{4} } &= 10.872\ \mathrm{ksi} \; \;\textrm{(St-Venant shear stress)}
# \end{aligned}
# $$

# %% [markdown]
# ## 9  Stub seat flange — two-way yield line
#
# Beam centered, tight bottom + side shims: the rigid HSS "plug" ties the stub top
# and bottom flanges, so a downward seat reaction hinges **both** flanges at the web
# line (capacity `2*phi*mp`). Because the flange is CJP'd to the cover plate across
# its full width, a pure fold about the web is not admissible — the collapse
# mechanism carries a **diagonal yield line** off the fixed CJP corner
# (region A rotates about the CJP edge, region B about the web; `internal/(mp*theta)
# = a + c + 2h^2/c`, minimized over the diagonal `c`).
#
# First the hand-checkable 1-way + sharing bound:

# %%
# %%render
# m_p     = F_y*t**2/4                       # plate plastic moment, kip-in per in
# phi_b   = 0.9
# cap_web = 2*phi_b*m_p                      # both flanges hinge at the web line
# z_w     = (b_stub - t)/2                   # remaining web line from centerline
# arm     = z_w                              # centered beam, load centroid at z=0
# L_brg   = 11*inch                          # shimmed bearing length (x)
# m_dem   = V_uy*arm/L_brg                   # web-line demand per length, 1-way
# DCR_seat_1way_shared = m_dem/cap_web
# Out:
# $$
# \begin{aligned}
# m_{p} &= F_{y} \cdot \frac{ \left( t \right) ^{ 2 } }{ 4 }  = 50.000\ \mathrm{ksi} \cdot \frac{ \left( 0.349\ \mathrm{inch} \right) ^{ 2 } }{ 4 } &= 1.523\ \mathrm{kip} \; \;\textrm{(plate plastic moment, kip-in per in)}
# \\
# \phi_{b} &= 0.9 \;
# \\
# \mathrm{cap}_{web} &= 2 \cdot \phi_{b} \cdot m_{p}  = 2 \cdot 0.9 \cdot 1.523\ \mathrm{kip} &= 2.741\ \mathrm{kip} \; \;\textrm{(both flanges hinge at the web line)}
# \\
# z_{w} &= \frac{ b_{stub} - t }{ 2 }  = \frac{ 6.000\ \mathrm{inch} - 0.349\ \mathrm{inch} }{ 2 } &= 2.825\ \mathrm{inch} \; \;\textrm{(remaining web line from centerline)}
# \\
# \mathrm{arm} &= 2.825\ \mathrm{inch} \; \;\textrm{(centered beam, load centroid at z=0)}
# \\
# L_{brg} &= 11 \cdot \mathrm{inch}  = 11 \cdot 1.000\ \mathrm{inch} &= 11.000\ \mathrm{inch} \; \;\textrm{(shimmed bearing length (x))}
# \\
# m_{dem} &= V_{uy} \cdot \frac{ \mathrm{arm} }{ L_{brg} }  = 8.900\ \mathrm{kip} \cdot \frac{ 2.825\ \mathrm{inch} }{ 11.000\ \mathrm{inch} } &= 2.286\ \mathrm{kip} \; \;\textrm{(web-line demand per length, 1-way)}
# \\
# \mathrm{DCR}_{seat_{1way_{shared}}} &= \frac{ m_{dem} }{ \mathrm{cap}_{web} }  = \frac{ 2.286\ \mathrm{kip} }{ 2.741\ \mathrm{kip} } &= 0.834
# \end{aligned}
# $$

# %% [markdown]
# Now the full two-way collapse (numeric minimization over the corner diagonal):

# %%
import numpy as np
Fy=50.0; tt=0.349; mp=Fy*tt**2/4; phib=0.9
Vuy=8.9
h_tip=(6-tt)/2 + 3.0                       # web CL to open outer edge
a=11.5                                     # flange length (CJP-fixed at xi=0)
eta_lo, eta_hi = (6-tt)/2-2, (6-tt)/2+2    # beam z=-2..+2 mapped from web
xi_lo, xi_hi   = 0.5, 11.5                 # beam-stub overlap
q = Vuy/((xi_hi-xi_lo)*(eta_hi-eta_lo))

N=400
xis=np.linspace(xi_lo,xi_hi,N); etas=np.linspace(eta_lo,eta_hi,N)
XI,ETA=np.meshgrid(xis,etas); dA=(xis[1]-xis[0])*(etas[1]-etas[0])
def qc_1flange(c):                         # single-flange collapse pressure
    inA = XI < c*ETA/h_tip                 # region A rotates about CJP edge
    w   = np.where(inA,(h_tip/c)*XI,ETA)   # w/theta field
    return mp*(a + c + 2*h_tip**2/c)/(np.sum(w)*dA)
cs=np.linspace(1.0,25,600)
qc=min(qc_1flange(c) for c in cs)          # yield-line minimum
DCR_seat_2way = q/(2*phib*qc)              # x2 for flange sharing, phi=0.9

print(f"collapse pressure (1 flange) qc = {sig(qc)} ksi   demand q = {sig(q)} ksi")
print(f"DCR (2-way + two-flange sharing) = {sig(DCR_seat_2way)}")
# Out:
# collapse pressure (1 flange) qc = 0.396 ksi   demand q = 0.202 ksi
# DCR (2-way + two-flange sharing) = 0.284

# %% [markdown]
# **Result — DCR ~ 0.28.** The seat clears comfortably and is insensitive to
# bearing length (stays ~0.25-0.28 down to a 5" footprint). The two-way action plus
# flange sharing removes the earlier 1-way concern. Guardrails: the ~2x sharing
# assumes the top clamp / bolt pretension is engaged (F2280 installs to pretension);
# and this remains a `Vuy`-only check under Path A.

# %% [markdown]
# ## 10  DCR summary

# %%
import pandas as pd
def f(x): return float(sig(float(x)))
rows = [
 ("Bolt shear (dbl shear, F2280 N)",        f(DCR_bolt_shear),   "OK"),
 ("Bolt bearing / tearout (t=0.349)",       f(DCR_bolt_bearing), "OK"),
 ("Beam tension-flange rupture (F13)",      f(DCR_beam_flange),  "OK"),
 ("Fillet weld group - base elastic",       f(DCR_weld_base),    "OK"),
 ("Fillet weld group - K5 eff width",       f(DCR_weld_K5),      "GOVERNS (watch)"),
 ("Cover plate flexure",                    f(DCR_plate),        "OK"),
 ("Column side-wall yield (beta=1, approx)",f(DCR_col_wall),     "OK"),
 ("Stub C-section flexure",                 f(DCR_stub_flex),    "OK"),
 ("Stub C-section shear",                   f(DCR_stub_shear),   "OK"),
 ("Seat flange - 2-way + sharing",          f(DCR_seat_2way),    "OK"),
]
df = pd.DataFrame(rows, columns=["Limit state","DCR","Status"])
print(f"Stub open-section St-Venant torsion: tau = {sig(float(tau_t))} ksi "
      f"(add warping + flexural shear)")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pandas as pd
#       2 def f(x): return float(sig(float(x)))
#       3 rows = [
#       4  ("Bolt shear (dbl shear, F2280 N)",        f(DCR_bolt_shear),   "OK"),
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## 11  Notes & export
#
# - **Governing:** fillet weld under the K5 effective-width treatment (~0.65; approaches
#   1.0 on the conservative flange-force interpretation) — consider 7/16" leg for margin.
# - **Path A premise** underlies the bolt and seat checks; keep the couple in the bolts.
# - **Verify separately:** stub open-section torsion combined with flexural shear;
#   a clean Chapter K column check; beam `Sx` against the AISC table; the beam member
#   under the combined H1 interaction.
# - **Bolt shear** uses `Fnv = 68 ksi` (threads included, N); if threads are excluded
#   (X, 84 ksi) all bolt DCRs drop ~19%.
#
# Export via the uploaded helper (writes to the project `outputs/` folder):

# %%
# export_notebook("html")   # or "pdf" (WeasyPrint backend on Colab)
export_notebook("html")
